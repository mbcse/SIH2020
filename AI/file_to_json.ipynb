# %%
import webbrowser
import json
import boto3
import io
from io import BytesIO
import sys
from pprint import pprint
import pdf2image
import os
import csv
import shutil

# %%
def extract_jpg(file_name,csv_output_file):
    table_csv = get_table_csv_results(file_name)
    with open(csv_output_file, "w") as fout:
        fout.write(table_csv)
    
    print('CSV OUTPUT FILE: ',csv_output_file)

# %%
def extract_pdf(file_name,csv_output_file):    
    from pdf2image import convert_from_path
    pages = convert_from_path(file_name, 500)
    table_csv=""
    for page in pages:
        page.save('out.jpeg', 'JPEG')
        table_csv+= get_table_csv_results('out.jpeg')
        os.remove("out.jpeg")
         
    with open(csv_output_file, "w") as fout:
        fout.write(table_csv)
        
    print('CSV OUTPUT FILE: ',csv_output_file)

# %%
def get_rows_columns_map(table_result, blocks_map):
    rows = {}
    for relationship in table_result['Relationships']:
        if relationship['Type'] == 'CHILD':
            for child_id in relationship['Ids']:
                cell = blocks_map[child_id]
                if cell['BlockType'] == 'CELL':
                    row_index = cell['RowIndex']
                    col_index = cell['ColumnIndex']
                    if row_index not in rows:
                        # create new row
                        rows[row_index] = {}
                        
                    # get the text value
                    rows[row_index][col_index] = get_text(cell, blocks_map)
    return rows


def get_text(result, blocks_map):
    text = ''
    if 'Relationships' in result:
        for relationship in result['Relationships']:
            if relationship['Type'] == 'CHILD':
                for child_id in relationship['Ids']:
                    word = blocks_map[child_id]
                    if word['BlockType'] == 'WORD':
                        text += word['Text'] + ' '
                    if word['BlockType'] == 'SELECTION_ELEMENT':
                        if word['SelectionStatus'] =='SELECTED':
                            text +=  'X '    
    return text


def get_table_csv_results(file_name):

    with open(file_name, 'rb') as file:
        img_test = file.read()
        bytes_test = bytearray(img_test)
        print('Image loaded', file_name)

    # process using image bytes
    # get the results
    client = boto3.client('textract')

    response = client.analyze_document(Document={'Bytes': bytes_test}, FeatureTypes=['TABLES'])

    # Get the text blocks
    blocks=response['Blocks']
    pprint(blocks)

    blocks_map = {}
    table_blocks = []
    for block in blocks:
        blocks_map[block['Id']] = block
        if block['BlockType'] == "TABLE":
            table_blocks.append(block)

    if len(table_blocks) <= 0:
        return "<b> NO Table FOUND </b>"

    csv = ''
    for index, table in enumerate(table_blocks):
        csv += generate_table_csv(table, blocks_map, index +1)
        csv += '\n\n'

    return csv

def generate_table_csv(table_result, blocks_map, table_index):
    rows = get_rows_columns_map(table_result, blocks_map)

    table_id = 'Table_' + str(table_index)
    
    # get cells.
    csv = 'Table: {0}\n\n'.format(table_id)

    for row_index, cols in rows.items():
        
        for col_index, text in cols.items():
            csv += '{}'.format(text) + ","
        csv += '\n'
        
    csv += '\n\n\n'
    return csv

# %%
def csv_json(file_name,json_output_file):
    file_name= csv_output_file
    rows=[]
    with open(file_name, 'r',encoding="utf8") as csvfile:        
        csvreader = csv.reader(csvfile) 

        # extracting field names through first row 
        fields = next(csvreader) 

        # extracting each data row one by one 
        for row in csvreader: 
            rows.append(row) 
            
    #removing empty lines
    master_list = []
    for i in range(len(rows)):  
        if(len(rows[i])>=2):
            master_list.append(rows[i])
            
    master_dict = {}
    for i in master_list:
        master_dict[i[0]] = i[1:]
        
    json_object = json.dumps(master_dict, indent = 4)    
    with open(json_output_file,'w') as outfile:
        json.dump(json_object, outfile)
        
    #print(json_object)    
    return json_object

# %%
def core_file_name(file_path):
    # This function has been created to get the actaul name of the file
    # i.e irrespective of any file extensions(.pdf/.jpg etc.) and path extensions(//.../../)
    # E.G: from asdf//dsfdsf/xyz.pdf it will return xyz only 
    
    #CAUTION : VERY NOOB CODE :P
    
    #removing the extension 
    file_path = file_path[::-1]
    file_less_ext = file_path[file_path.index('.')+1:][::-1]
    
    #print(file_less_ext)
    
    #removing the path to get the actual name
    if(file_less_ext[::-1].index("/")):
        #path_index = file_less_ext[::-1].index("/")        
        temp_less_path = file_less_ext[::-1]        
        temp_less_path=temp_less_path[:temp_less_path.index('/')]
        final_name = temp_less_path[::-1]
        
    else:
        final_name = file_less_ext
        
    return final_name

# %%
file_name = 'Forms/Land Owner Consent Form.pdf'
output_file_name = core_file_name(file_name)
#print(output_file_name)

csv_output_file = output_file_name+'.csv'
if(file_name[-3:]=="pdf"):
    extract_pdf(file_name,csv_output_file)
    
else:
    extract_jpg(file_name,csv_output_file)
    
json_output_file = output_file_name+'.json'    
result = csv_json(csv_output_file,json_output_file)
print(result)
# Out:
# Image loaded out.jpeg
# [{'BlockType': 'PAGE',
#   'Geometry': {'BoundingBox': {'Height': 1.0,
#                                'Left': 0.0,
#                                'Top': 0.0,
#                                'Width': 1.0},
#                'Polygon': [{'X': 0.0, 'Y': 0.0},
#                            {'X': 1.0, 'Y': 0.0},
#                            {'X': 1.0, 'Y': 1.0},
#                            {'X': 0.0, 'Y': 1.0}]},
#   'Id': '842b07eb-c5cb-42ed-ab72-87d3f1821722',
#   'Relationships': [{'Ids': ['0525b0e3-a9ac-403f-8a6d-d9fc8a95d430',
#                              '5add532e-7341-432b-88ad-98885b68eb7f',
#                              '8ffe8061-8b0a-4cf9-a791-f147ed57bb0b',
#                              'a2e26e82-bf92-4336-8bd0-f60b0375db44',
#                              '3763124e-1197-4bdc-8bb9-dac69135abf2',
#                              '5d889194-d28f-4648-bab1-a5b343d98be6',
#                              'c95fe97d-13a6-4fd1-b09e-e76568adec85',
#                              '5490d259-2ac1-49b1-8520-007583de8698',
#                              '1dedd886-bce0-4132-bec8-442d3799e9b3',
#                              '41df425d-8878-4448-8ac8-edb48696cb21',
#                              '00ccf10e-0636-4442-8909-e4e83a395f62',
#                              '656d393a-7b49-45d7-bdde-5691491c5a99',
#                              'ceeb8dd9-7205-4270-bd01-414bb1e35b3b',
#                              '51faf413-2a50-42ff-89a1-bbe6bf5bde27',
#                              'e37bea22-32e7-42ba-b3ff-27edb988a633',
#                              '8ad09b2b-c771-4205-89c9-366e891d3854',
#                              'b24bbc2c-5bc1-45e2-aba1-1a5e2917a130',
#                              '1cf3b09d-5224-4b3d-8835-8b5b9d21ad74',
#                              'df25db6d-70cb-4da6-8d08-afecf4b52d77',
#                              'a6a7c01f-555c-4207-9114-f90e896d3323',
#                              'b4c6e0be-ee16-4152-97f7-54270637fa34',
#                              'b6c41324-abc2-4d62-8725-bf0a1cd8a373',
#                              '1d0a70fe-f9cf-4bf8-affd-d59fd98e36cc',
#                              '559c093c-8fb8-45c1-b774-47b69e9f1f5a',
#                              '30545155-20a8-4391-94ce-c39333ac7db3',
#                              '09c6aa54-c37b-4f47-a625-a6c57233db6d',
#                              '59dd8300-09be-47c2-9974-fc21100c5e97',
#                              '8863e5c2-93ee-48fe-9f95-ab31d0a6e4c3',
#                              '1697106a-485c-4ba6-bc11-67be8904e905',
#                              '4442e7a1-8c0c-4594-9b49-d324bbebaf08',
#                              'd00bdece-1b61-4f81-b86c-4b804105a3c4',
#                              '607e3930-1d12-4eb2-825c-46c76268c5ca',
#                              'b78be3cd-131d-4f58-bab7-62b923c91163',
#                              '944d67b6-f967-4709-9695-df454560b420',
#                              'dff3583f-2e02-4ff5-8c40-b532ed69d26c',
#                              'cab39449-0083-43ec-88d3-296abfc6532e'],
#                      'Type': 'CHILD'}]},
#  {'BlockType': 'LINE',
#   'Confidence': 99.87434387207031,
#   'Geometry': {'BoundingBox': {'Height': 0.016476457938551903,
#                                'Left': 0.32446542382240295,
#                                'Top': 0.06981603801250458,
#                                'Width': 0.3495257794857025},
#                'Polygon': [{'X': 0.32446542382240295, 'Y': 0.06981603801250458},
#                            {'X': 0.6739912033081055, 'Y': 0.06981603801250458},
#                            {'X': 0.6739912033081055, 'Y': 0.08629249781370163},
#                            {'X': 0.32446542382240295,
#                             'Y': 0.08629249781370163}]},
#   'Id': '0525b0e3-a9ac-403f-8a6d-d9fc8a95d430',
#   'Relationships': [{'Ids': ['42c0f75c-9f89-4e8b-9101-91eb61e800e5',
#                              '8efc8e0c-9d9f-46a0-bb8e-067331bd9017',
#                              '5474ab59-6ae9-4489-a6a3-c1bc16e83192',
#                              '24ac5cf5-da35-4222-a649-c8406974fd94'],
#                      'Type': 'CHILD'}],
#   'Text': 'Land Owner Consent Form'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.7114028930664,
#   'Geometry': {'BoundingBox': {'Height': 0.01147832628339529,
#                                'Left': 0.1578006148338318,
#                                'Top': 0.10546708852052689,
#                                'Width': 0.12783044576644897},
#                'Polygon': [{'X': 0.1578006148338318, 'Y': 0.10546708852052689},
#                            {'X': 0.28563106060028076, 'Y': 0.10546708852052689},
#                            {'X': 0.28563106060028076, 'Y': 0.11694541573524475},
#                            {'X': 0.1578006148338318,
#                             'Y': 0.11694541573524475}]},
#   'Id': '5add532e-7341-432b-88ad-98885b68eb7f',
#   'Relationships': [{'Ids': ['78be2dcb-e5db-4f2a-83ba-aea0856353e7',
#                              '7d45554e-efb9-49b4-a6db-835dbeefe718',
#                              '935538a0-b7f3-402e-86bd-0e93a7f3b2c3'],
#                      'Type': 'CHILD'}],
#   'Text': 'Name of Owner'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.76615905761719,
#   'Geometry': {'BoundingBox': {'Height': 0.011632047593593597,
#                                'Left': 0.4188355803489685,
#                                'Top': 0.10553266853094101,
#                                'Width': 0.12981754541397095},
#                'Polygon': [{'X': 0.4188355803489685, 'Y': 0.10553266853094101},
#                            {'X': 0.5486531257629395, 'Y': 0.10553266853094101},
#                            {'X': 0.5486531257629395, 'Y': 0.1171647161245346},
#                            {'X': 0.4188355803489685, 'Y': 0.1171647161245346}]},
#   'Id': '8ffe8061-8b0a-4cf9-a791-f147ed57bb0b',
#   'Relationships': [{'Ids': ['7866ec06-8fdc-4c41-ab82-57c17b8b7d5b',
#                              'e6dd92e0-70a7-4e3d-be1e-c4e4dd7fb53e'],
#                      'Type': 'CHILD'}],
#   'Text': 'Shambu Sharma'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.71680450439453,
#   'Geometry': {'BoundingBox': {'Height': 0.011628652922809124,
#                                'Left': 0.15774068236351013,
#                                'Top': 0.12669622898101807,
#                                'Width': 0.1472126841545105},
#                'Polygon': [{'X': 0.15774068236351013, 'Y': 0.12669622898101807},
#                            {'X': 0.30495336651802063, 'Y': 0.12669622898101807},
#                            {'X': 0.30495336651802063, 'Y': 0.13832488656044006},
#                            {'X': 0.15774068236351013,
#                             'Y': 0.13832488656044006}]},
#   'Id': 'a2e26e82-bf92-4336-8bd0-f60b0375db44',
#   'Relationships': [{'Ids': ['fa1f06c5-27ac-48b0-8745-0daeb37c1a72',
#                              '8215e14e-8ef0-4b2f-b944-5bc95430eddd',
#                              '8037941b-60df-4139-b4f1-12f14d23fce8'],
#                      'Type': 'CHILD'}],
#   'Text': 'Phone Number Of'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.63196563720703,
#   'Geometry': {'BoundingBox': {'Height': 0.011581003665924072,
#                                'Left': 0.4196041524410248,
#                                'Top': 0.1268470287322998,
#                                'Width': 0.11471471190452576},
#                'Polygon': [{'X': 0.4196041524410248, 'Y': 0.1268470287322998},
#                            {'X': 0.5343188643455505, 'Y': 0.1268470287322998},
#                            {'X': 0.5343188643455505, 'Y': 0.13842803239822388},
#                            {'X': 0.4196041524410248,
#                             'Y': 0.13842803239822388}]},
#   'Id': '3763124e-1197-4bdc-8bb9-dac69135abf2',
#   'Relationships': [{'Ids': ['c1121f96-ecfd-46c1-a23d-48f94d56e85a'],
#                      'Type': 'CHILD'}],
#   'Text': '0120-1234569'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.79407501220703,
#   'Geometry': {'BoundingBox': {'Height': 0.011087128892540932,
#                                'Left': 0.1580643206834793,
#                                'Top': 0.14320598542690277,
#                                'Width': 0.09939952939748764},
#                'Polygon': [{'X': 0.1580643206834793, 'Y': 0.14320598542690277},
#                            {'X': 0.25746384263038635, 'Y': 0.14320598542690277},
#                            {'X': 0.25746384263038635, 'Y': 0.15429311990737915},
#                            {'X': 0.1580643206834793,
#                             'Y': 0.15429311990737915}]},
#   'Id': '5d889194-d28f-4648-bab1-a5b343d98be6',
#   'Relationships': [{'Ids': ['ee862bca-4f80-4835-8e03-ae3157240cbf',
#                              '6d1b4a04-9f80-42d1-9753-2beef95bba10'],
#                      'Type': 'CHILD'}],
#   'Text': 'Land Owner'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.92540740966797,
#   'Geometry': {'BoundingBox': {'Height': 0.0113144526258111,
#                                'Left': 0.15814664959907532,
#                                'Top': 0.16449524462223053,
#                                'Width': 0.15345805883407593},
#                'Polygon': [{'X': 0.15814664959907532, 'Y': 0.16449524462223053},
#                            {'X': 0.31160470843315125, 'Y': 0.16449524462223053},
#                            {'X': 0.31160470843315125, 'Y': 0.17580969631671906},
#                            {'X': 0.15814664959907532,
#                             'Y': 0.17580969631671906}]},
#   'Id': 'c95fe97d-13a6-4fd1-b09e-e76568adec85',
#   'Relationships': [{'Ids': ['94a33dd8-c2f1-49f9-b99a-5395f17417c2',
#                              '9c7826ce-6e6c-42f7-ada1-0e46476e91ec'],
#                      'Type': 'CHILD'}],
#   'Text': 'Permanent Address'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.9158706665039,
#   'Geometry': {'BoundingBox': {'Height': 0.013653844594955444,
#                                'Left': 0.41905486583709717,
#                                'Top': 0.1646329164505005,
#                                'Width': 0.19490139186382294},
#                'Polygon': [{'X': 0.41905486583709717, 'Y': 0.1646329164505005},
#                            {'X': 0.6139562726020813, 'Y': 0.1646329164505005},
#                            {'X': 0.6139562726020813, 'Y': 0.17828676104545593},
#                            {'X': 0.41905486583709717,
#                             'Y': 0.17828676104545593}]},
#   'Id': '5490d259-2ac1-49b1-8520-007583de8698',
#   'Relationships': [{'Ids': ['e6f47269-0eb8-47ce-9f35-842c96ff5fbe',
#                              '9de329bb-a8ec-451d-9f00-2798f73ba849',
#                              '346d382c-17d0-4abf-963b-e4fc7a9d7af3'],
#                      'Type': 'CHILD'}],
#   'Text': 'Balampur, Uttar Pradesh'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.41433715820312,
#   'Geometry': {'BoundingBox': {'Height': 0.011346995830535889,
#                                'Left': 0.15792933106422424,
#                                'Top': 0.18038107454776764,
#                                'Width': 0.12131146341562271},
#                'Polygon': [{'X': 0.15792933106422424, 'Y': 0.18038107454776764},
#                            {'X': 0.27924078702926636, 'Y': 0.18038107454776764},
#                            {'X': 0.27924078702926636, 'Y': 0.19172807037830353},
#                            {'X': 0.15792933106422424,
#                             'Y': 0.19172807037830353}]},
#   'Id': '1dedd886-bce0-4132-bec8-442d3799e9b3',
#   'Relationships': [{'Ids': ['a5f63a5f-bcfb-4cf5-a013-9ddeddc269da',
#                              '7370ddc8-35cf-4eff-ab3a-b40d3a421289',
#                              'd6c97c5d-235c-46c6-9e86-19948267e5a5'],
#                      'Type': 'CHILD'}],
#   'Text': 'of Land Owner'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.7623291015625,
#   'Geometry': {'BoundingBox': {'Height': 0.014119163155555725,
#                                'Left': 0.15801624953746796,
#                                'Top': 0.2016945779323578,
#                                'Width': 0.22751106321811676},
#                'Polygon': [{'X': 0.15801624953746796, 'Y': 0.2016945779323578},
#                            {'X': 0.3855273127555847, 'Y': 0.2016945779323578},
#                            {'X': 0.3855273127555847, 'Y': 0.2158137410879135},
#                            {'X': 0.15801624953746796,
#                             'Y': 0.2158137410879135}]},
#   'Id': '41df425d-8878-4448-8ac8-edb48696cb21',
#   'Relationships': [{'Ids': ['3c90b8c2-30a6-4f2b-9193-9d46a91ebe16',
#                              '122ec9b6-d51f-4ddd-a820-4428e68771f3',
#                              '2e91b352-949f-40e7-a29b-e933a9e5989c',
#                              'e4f081e3-fe46-4533-b40c-40de113bfa5e'],
#                      'Type': 'CHILD'}],
#   'Text': 'Name of buyer organization/'},
#  {'BlockType': 'LINE',
#   'Confidence': 95.1685562133789,
#   'Geometry': {'BoundingBox': {'Height': 0.011023610830307007,
#                                'Left': 0.41866904497146606,
#                                'Top': 0.20210057497024536,
#                                'Width': 0.035283446311950684},
#                'Polygon': [{'X': 0.41866904497146606, 'Y': 0.20210057497024536},
#                            {'X': 0.45395249128341675, 'Y': 0.20210057497024536},
#                            {'X': 0.45395249128341675, 'Y': 0.21312418580055237},
#                            {'X': 0.41866904497146606,
#                             'Y': 0.21312418580055237}]},
#   'Id': '00ccf10e-0636-4442-8909-e4e83a395f62',
#   'Relationships': [{'Ids': ['01db99e2-d4cd-40f0-bbf6-59b55df68172'],
#                      'Type': 'CHILD'}],
#   'Text': 'AAI'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.87657165527344,
#   'Geometry': {'BoundingBox': {'Height': 0.011473149061203003,
#                                'Left': 0.158281147480011,
#                                'Top': 0.2177370935678482,
#                                'Width': 0.08063602447509766},
#                'Polygon': [{'X': 0.158281147480011, 'Y': 0.2177370935678482},
#                            {'X': 0.23891717195510864, 'Y': 0.2177370935678482},
#                            {'X': 0.23891717195510864, 'Y': 0.2292102426290512},
#                            {'X': 0.158281147480011, 'Y': 0.2292102426290512}]},
#   'Id': '656d393a-7b49-45d7-bdde-5691491c5a99',
#   'Relationships': [{'Ids': ['08248356-ba9a-43d7-9e85-9dd1bd7d79ea'],
#                      'Type': 'CHILD'}],
#   'Text': 'Individual'},
#  {'BlockType': 'LINE',
#   'Confidence': 98.08602142333984,
#   'Geometry': {'BoundingBox': {'Height': 0.011415617540478706,
#                                'Left': 0.15806961059570312,
#                                'Top': 0.2393539696931839,
#                                'Width': 0.20330756902694702},
#                'Polygon': [{'X': 0.15806961059570312, 'Y': 0.2393539696931839},
#                            {'X': 0.36137717962265015, 'Y': 0.2393539696931839},
#                            {'X': 0.36137717962265015, 'Y': 0.25076958537101746},
#                            {'X': 0.15806961059570312,
#                             'Y': 0.25076958537101746}]},
#   'Id': 'ceeb8dd9-7205-4270-bd01-414bb1e35b3b',
#   'Relationships': [{'Ids': ['7ef5943d-de2d-45ab-ac97-a62d4325c73c',
#                              '5c4493ef-cea7-476b-96c4-2a5096298853',
#                              'bc52e16b-f112-4a42-99da-4579c7bd0ff4',
#                              '08dfa79b-5d10-4a8a-9919-0f333abcc1eb'],
#                      'Type': 'CHILD'}],
#   'Text': 'Phone Number Of Owner'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.62513732910156,
#   'Geometry': {'BoundingBox': {'Height': 0.01165008544921875,
#                                'Left': 0.4177606403827667,
#                                'Top': 0.23917478322982788,
#                                'Width': 0.10524728894233704},
#                'Polygon': [{'X': 0.4177606403827667, 'Y': 0.23917478322982788},
#                            {'X': 0.5230079293251038, 'Y': 0.23917478322982788},
#                            {'X': 0.5230079293251038, 'Y': 0.25082486867904663},
#                            {'X': 0.4177606403827667,
#                             'Y': 0.25082486867904663}]},
#   'Id': '51faf413-2a50-42ff-89a1-bbe6bf5bde27',
#   'Relationships': [{'Ids': ['1f888e66-006b-468d-bfa8-758e15534285'],
#                      'Type': 'CHILD'}],
#   'Text': '011-5669742'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.94163513183594,
#   'Geometry': {'BoundingBox': {'Height': 0.013814955949783325,
#                                'Left': 0.15800358355045319,
#                                'Top': 0.26080313324928284,
#                                'Width': 0.25642335414886475},
#                'Polygon': [{'X': 0.15800358355045319, 'Y': 0.26080313324928284},
#                            {'X': 0.41442692279815674, 'Y': 0.26080313324928284},
#                            {'X': 0.41442692279815674, 'Y': 0.27461808919906616},
#                            {'X': 0.15800358355045319,
#                             'Y': 0.27461808919906616}]},
#   'Id': 'e37bea22-32e7-42ba-b3ff-27edb988a633',
#   'Relationships': [{'Ids': ['44533410-e23f-4cf9-9ef7-045876e048e7',
#                              'b20fbb47-44d2-4bc0-9bdc-45836d283c2a',
#                              '6ce76acf-5d19-421c-a7cb-2826b457fc02'],
#                      'Type': 'CHILD'}],
#   'Text': 'Permanent Address organization'},
#  {'BlockType': 'LINE',
#   'Confidence': 98.40184783935547,
#   'Geometry': {'BoundingBox': {'Height': 0.01130443625152111,
#                                'Left': 0.4179544448852539,
#                                'Top': 0.2606905400753021,
#                                'Width': 0.0871470645070076},
#                'Polygon': [{'X': 0.4179544448852539, 'Y': 0.2606905400753021},
#                            {'X': 0.5051015019416809, 'Y': 0.2606905400753021},
#                            {'X': 0.5051015019416809, 'Y': 0.2719949781894684},
#                            {'X': 0.4179544448852539, 'Y': 0.2719949781894684}]},
#   'Id': '8ad09b2b-c771-4205-89c9-366e891d3854',
#   'Relationships': [{'Ids': ['6cde3c15-31f4-4f7c-9a0a-cdbaa62ee009',
#                              'fdd9eab1-f3f1-43e9-9951-5534ada18fcf'],
#                      'Type': 'CHILD'}],
#   'Text': 'New Delhi'},
#  {'BlockType': 'LINE',
#   'Confidence': 97.29165649414062,
#   'Geometry': {'BoundingBox': {'Height': 0.013033002614974976,
#                                'Left': 0.6524500846862793,
#                                'Top': 0.2609884440898895,
#                                'Width': 0.05331599712371826},
#                'Polygon': [{'X': 0.6524500846862793, 'Y': 0.2609884440898895},
#                            {'X': 0.7057660818099976, 'Y': 0.2609884440898895},
#                            {'X': 0.7057660818099976, 'Y': 0.2740214467048645},
#                            {'X': 0.6524500846862793, 'Y': 0.2740214467048645}]},
#   'Id': 'b24bbc2c-5bc1-45e2-aba1-1a5e2917a130',
#   'Relationships': [{'Ids': ['784698cb-c945-4f37-8ea0-827f258b2ab0'],
#                      'Type': 'CHILD'}],
#   'Text': 'A-123,'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.90385437011719,
#   'Geometry': {'BoundingBox': {'Height': 0.011591672897338867,
#                                'Left': 0.15805277228355408,
#                                'Top': 0.2764282524585724,
#                                'Width': 0.08108106255531311},
#                'Polygon': [{'X': 0.15805277228355408, 'Y': 0.2764282524585724},
#                            {'X': 0.2391338348388672, 'Y': 0.2764282524585724},
#                            {'X': 0.2391338348388672, 'Y': 0.28801992535591125},
#                            {'X': 0.15805277228355408,
#                             'Y': 0.28801992535591125}]},
#   'Id': '1cf3b09d-5224-4b3d-8835-8b5b9d21ad74',
#   'Relationships': [{'Ids': ['aeedb4b0-eabd-4b48-be21-915f3131c492'],
#                      'Type': 'CHILD'}],
#   'Text': 'Individual'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.89704132080078,
#   'Geometry': {'BoundingBox': {'Height': 0.013934284448623657,
#                                'Left': 0.6513065695762634,
#                                'Top': 0.27647948265075684,
#                                'Width': 0.15420076251029968},
#                'Polygon': [{'X': 0.6513065695762634, 'Y': 0.27647948265075684},
#                            {'X': 0.8055073022842407, 'Y': 0.27647948265075684},
#                            {'X': 0.8055073022842407, 'Y': 0.2904137670993805},
#                            {'X': 0.6513065695762634, 'Y': 0.2904137670993805}]},
#   'Id': 'df25db6d-70cb-4da6-8d08-afecf4b52d77',
#   'Relationships': [{'Ids': ['35c923f5-7f54-47d9-a21b-535f42fcd8b9',
#                              'cfbae809-1108-4dfc-9ce8-0f9af27a84cb'],
#                      'Type': 'CHILD'}],
#   'Text': 'Safdarjung Enclave'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.80662536621094,
#   'Geometry': {'BoundingBox': {'Height': 0.011400772258639336,
#                                'Left': 0.15771178901195526,
#                                'Top': 0.29776841402053833,
#                                'Width': 0.15221799910068512},
#                'Polygon': [{'X': 0.15771178901195526, 'Y': 0.29776841402053833},
#                            {'X': 0.3099297881126404, 'Y': 0.29776841402053833},
#                            {'X': 0.3099297881126404, 'Y': 0.3091691732406616},
#                            {'X': 0.15771178901195526,
#                             'Y': 0.3091691732406616}]},
#   'Id': 'a6a7c01f-555c-4207-9114-f90e896d3323',
#   'Relationships': [{'Ids': ['6114852c-e317-471c-b621-33d16527885d',
#                              '517c0a85-bf14-4c65-bedf-df1d912f55b0',
#                              'd8454a3c-afc1-461e-b181-080eb812077d',
#                              '634d49cf-97e6-44af-b4e9-8b6c16a6ae1e'],
#                      'Type': 'CHILD'}],
#   'Text': 'Total Area of Land'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.7473373413086,
#   'Geometry': {'BoundingBox': {'Height': 0.011411994695663452,
#                                'Left': 0.41875115036964417,
#                                'Top': 0.29800286889076233,
#                                'Width': 0.05982586741447449},
#                'Polygon': [{'X': 0.41875115036964417, 'Y': 0.29800286889076233},
#                            {'X': 0.47857701778411865, 'Y': 0.29800286889076233},
#                            {'X': 0.47857701778411865, 'Y': 0.3094148635864258},
#                            {'X': 0.41875115036964417,
#                             'Y': 0.3094148635864258}]},
#   'Id': 'b4c6e0be-ee16-4152-97f7-54270637fa34',
#   'Relationships': [{'Ids': ['fd9083c3-0ead-483e-9862-4fd41daf84e6'],
#                      'Type': 'CHILD'}],
#   'Text': '20acres'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.71759033203125,
#   'Geometry': {'BoundingBox': {'Height': 0.012297624722123146,
#                                'Left': 0.157674640417099,
#                                'Top': 0.3184296488761902,
#                                'Width': 0.14988228678703308},
#                'Polygon': [{'X': 0.157674640417099, 'Y': 0.3184296488761902},
#                            {'X': 0.3075569272041321, 'Y': 0.3184296488761902},
#                            {'X': 0.3075569272041321, 'Y': 0.3307272791862488},
#                            {'X': 0.157674640417099, 'Y': 0.3307272791862488}]},
#   'Id': 'b6c41324-abc2-4d62-8725-bf0a1cd8a373',
#   'Relationships': [{'Ids': ['2debb045-f9d8-4647-9c72-df8c7687c277',
#                              '07fe0a7b-12fe-4528-8cbc-eeb0670c4826',
#                              '819434f5-0c4e-49d5-a27b-8f5527e521d6',
#                              '5d9ce59b-f083-4221-9748-d92220363689'],
#                      'Type': 'CHILD'}],
#   'Text': 'Total Cost of Land'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.85113525390625,
#   'Geometry': {'BoundingBox': {'Height': 0.0107516348361969,
#                                'Left': 0.41813042759895325,
#                                'Top': 0.3197641372680664,
#                                'Width': 0.0271776020526886},
#                'Polygon': [{'X': 0.41813042759895325, 'Y': 0.3197641372680664},
#                            {'X': 0.44530802965164185, 'Y': 0.3197641372680664},
#                            {'X': 0.44530802965164185, 'Y': 0.3305157721042633},
#                            {'X': 0.41813042759895325,
#                             'Y': 0.3305157721042633}]},
#   'Id': '1d0a70fe-f9cf-4bf8-affd-d59fd98e36cc',
#   'Relationships': [{'Ids': ['ec356083-4531-41a9-b030-731ae5009e67'],
#                      'Type': 'CHILD'}],
#   'Text': '2cr'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.62191009521484,
#   'Geometry': {'BoundingBox': {'Height': 0.012026727199554443,
#                                'Left': 0.1582898199558258,
#                                'Top': 0.3401867747306824,
#                                'Width': 0.1225312352180481},
#                'Polygon': [{'X': 0.1582898199558258, 'Y': 0.3401867747306824},
#                            {'X': 0.2808210551738739, 'Y': 0.3401867747306824},
#                            {'X': 0.2808210551738739, 'Y': 0.3522135019302368},
#                            {'X': 0.1582898199558258, 'Y': 0.3522135019302368}]},
#   'Id': '559c093c-8fb8-45c1-b774-47b69e9f1f5a',
#   'Relationships': [{'Ids': ['fc37f83e-43fa-4143-b234-3eaf29ae501b',
#                              'ef02a71f-131c-42f0-b33b-1a7b574ac695',
#                              'b49ea5b4-c36d-410d-8995-e820196502b4'],
#                      'Type': 'CHILD'}],
#   'Text': 'Address of Plot'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.8759536743164,
#   'Geometry': {'BoundingBox': {'Height': 0.013799518346786499,
#                                'Left': 0.4177205562591553,
#                                'Top': 0.34074723720550537,
#                                'Width': 0.11025302857160568},
#                'Polygon': [{'X': 0.4177205562591553, 'Y': 0.34074723720550537},
#                            {'X': 0.5279735922813416, 'Y': 0.34074723720550537},
#                            {'X': 0.5279735922813416, 'Y': 0.35454675555229187},
#                            {'X': 0.4177205562591553,
#                             'Y': 0.35454675555229187}]},
#   'Id': '30545155-20a8-4391-94ce-c39333ac7db3',
#   'Relationships': [{'Ids': ['47564a43-38ce-454e-9da5-3c7bf1bd87ed',
#                              'c23b374e-5423-4bf6-84b7-ecdf9bc28fef'],
#                      'Type': 'CHILD'}],
#   'Text': 'Jewar Village'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.79676818847656,
#   'Geometry': {'BoundingBox': {'Height': 0.014354795217514038,
#                                'Left': 0.6504983901977539,
#                                'Top': 0.34067559242248535,
#                                'Width': 0.18588799238204956},
#                'Polygon': [{'X': 0.6504983901977539, 'Y': 0.34067559242248535},
#                            {'X': 0.8363863825798035, 'Y': 0.34067559242248535},
#                            {'X': 0.8363863825798035, 'Y': 0.3550303876399994},
#                            {'X': 0.6504983901977539, 'Y': 0.3550303876399994}]},
#   'Id': '09c6aa54-c37b-4f47-a625-a6c57233db6d',
#   'Relationships': [{'Ids': ['b9f5735e-b6ba-4607-b250-5b3f892dfbf7',
#                              '78f3af00-e4c1-44fe-8ad2-44d3a8ba0268',
#                              '40bb6bdc-79b8-4a53-b889-69a429f656e7'],
#                      'Type': 'CHILD'}],
#   'Text': 'X-987 opposite Mandir'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.93885040283203,
#   'Geometry': {'BoundingBox': {'Height': 0.014365489594638348,
#                                'Left': 0.15870344638824463,
#                                'Top': 0.3619038462638855,
#                                'Width': 0.2477613091468811},
#                'Polygon': [{'X': 0.15870344638824463, 'Y': 0.3619038462638855},
#                            {'X': 0.40646475553512573, 'Y': 0.3619038462638855},
#                            {'X': 0.40646475553512573, 'Y': 0.3762693405151367},
#                            {'X': 0.15870344638824463,
#                             'Y': 0.3762693405151367}]},
#   'Id': '59dd8300-09be-47c2-9974-fc21100c5e97',
#   'Relationships': [{'Ids': ['b9c746d5-9504-46a1-983f-667a98c0d75b',
#                              '5cdd0886-d45d-4396-8623-ac3e31511437',
#                              '3c26d046-8a3d-49e6-a687-d34e989e0ba6',
#                              '5d72601b-eff1-4fe8-a781-7a64c104167c'],
#                      'Type': 'CHILD'}],
#   'Text': 'Approval from Local Authority'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.95619201660156,
#   'Geometry': {'BoundingBox': {'Height': 0.011121302843093872,
#                                'Left': 0.4180140793323517,
#                                'Top': 0.36229804158210754,
#                                'Width': 0.043885737657547},
#                'Polygon': [{'X': 0.4180140793323517, 'Y': 0.36229804158210754},
#                            {'X': 0.4618998169898987, 'Y': 0.36229804158210754},
#                            {'X': 0.4618998169898987, 'Y': 0.3734193444252014},
#                            {'X': 0.4180140793323517, 'Y': 0.3734193444252014}]},
#   'Id': '8863e5c2-93ee-48fe-9f95-ab31d0a6e4c3',
#   'Relationships': [{'Ids': ['1bc566c9-ce7e-46aa-bf9a-7b4e9f29afcb'],
#                      'Type': 'CHILD'}],
#   'Text': 'Done'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.42083740234375,
#   'Geometry': {'BoundingBox': {'Height': 0.011471599340438843,
#                                'Left': 0.6505581736564636,
#                                'Top': 0.36210891604423523,
#                                'Width': 0.15033748745918274},
#                'Polygon': [{'X': 0.6505581736564636, 'Y': 0.36210891604423523},
#                            {'X': 0.8008956909179688, 'Y': 0.36210891604423523},
#                            {'X': 0.8008956909179688, 'Y': 0.3735805153846741},
#                            {'X': 0.6505581736564636, 'Y': 0.3735805153846741}]},
#   'Id': '1697106a-485c-4ba6-bc11-67be8904e905',
#   'Relationships': [{'Ids': ['907b36ef-ee37-430b-87d1-87014a106e3d',
#                              '84b14437-26ea-4272-96bc-e1fe7c06c12d',
#                              '66301fba-0e19-47ff-be02-7cc9adffc86f',
#                              'b578f9bc-7a5e-4984-ad3c-65a5e0818389'],
#                      'Type': 'CHILD'}],
#   'Text': 'On 7-5-19 at 14:00'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.81424713134766,
#   'Geometry': {'BoundingBox': {'Height': 0.014503548853099346,
#                                'Left': 0.1576267033815384,
#                                'Top': 0.3826742172241211,
#                                'Width': 0.16369099915027618},
#                'Polygon': [{'X': 0.1576267033815384, 'Y': 0.3826742172241211},
#                            {'X': 0.3213177025318146, 'Y': 0.3826742172241211},
#                            {'X': 0.3213177025318146, 'Y': 0.3971777558326721},
#                            {'X': 0.1576267033815384, 'Y': 0.3971777558326721}]},
#   'Id': '4442e7a1-8c0c-4594-9b49-d324bbebaf08',
#   'Relationships': [{'Ids': ['3953883c-6da8-4301-be19-8fa4327b3ca2',
#                              'a5ff092f-901a-443b-9dd6-55a5eaf09999',
#                              '435f2683-b4cb-4505-9eb5-fc44cc7870fb',
#                              '1f13b512-bc00-4425-acc2-de8b0b79cf5c'],
#                      'Type': 'CHILD'}],
#   'Text': 'Loan taken by buyer'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.94379425048828,
#   'Geometry': {'BoundingBox': {'Height': 0.011231452226638794,
#                                'Left': 0.41807663440704346,
#                                'Top': 0.3837203085422516,
#                                'Width': 0.04355984926223755},
#                'Polygon': [{'X': 0.41807663440704346, 'Y': 0.3837203085422516},
#                            {'X': 0.461636483669281, 'Y': 0.3837203085422516},
#                            {'X': 0.461636483669281, 'Y': 0.3949517607688904},
#                            {'X': 0.41807663440704346,
#                             'Y': 0.3949517607688904}]},
#   'Id': 'd00bdece-1b61-4f81-b86c-4b804105a3c4',
#   'Relationships': [{'Ids': ['27e58a3e-73b3-4da6-9f23-4c85e2e94e5f'],
#                      'Type': 'CHILD'}],
#   'Text': 'None'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.94961547851562,
#   'Geometry': {'BoundingBox': {'Height': 0.013908863067626953,
#                                'Left': 0.1576029658317566,
#                                'Top': 0.4047887325286865,
#                                'Width': 0.1806110143661499},
#                'Polygon': [{'X': 0.1576029658317566, 'Y': 0.4047887325286865},
#                            {'X': 0.3382139801979065, 'Y': 0.4047887325286865},
#                            {'X': 0.3382139801979065, 'Y': 0.4186975955963135},
#                            {'X': 0.1576029658317566, 'Y': 0.4186975955963135}]},
#   'Id': '607e3930-1d12-4eb2-825c-46c76268c5ca',
#   'Relationships': [{'Ids': ['779c6801-5592-469c-902b-8795601aac31',
#                              '5cec1b83-e129-4783-aa4d-bd3949eed78c',
#                              '6a43499f-35e2-4e15-95e1-90567d2f5b02'],
#                      'Type': 'CHILD'}],
#   'Text': 'Total Capital inversted'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.82618713378906,
#   'Geometry': {'BoundingBox': {'Height': 0.011065691709518433,
#                                'Left': 0.4185265898704529,
#                                'Top': 0.40532949566841125,
#                                'Width': 0.026809513568878174},
#                'Polygon': [{'X': 0.4185265898704529, 'Y': 0.40532949566841125},
#                            {'X': 0.44533610343933105, 'Y': 0.40532949566841125},
#                            {'X': 0.44533610343933105, 'Y': 0.4163951873779297},
#                            {'X': 0.4185265898704529, 'Y': 0.4163951873779297}]},
#   'Id': 'b78be3cd-131d-4f58-bab7-62b923c91163',
#   'Relationships': [{'Ids': ['03ed1671-b141-4ac9-a336-292b32257d92'],
#                      'Type': 'CHILD'}],
#   'Text': '2cr'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.91909790039062,
#   'Geometry': {'BoundingBox': {'Height': 0.013907790184020996,
#                                'Left': 0.15795785188674927,
#                                'Top': 0.4263925850391388,
#                                'Width': 0.1932448148727417},
#                'Polygon': [{'X': 0.15795785188674927, 'Y': 0.4263925850391388},
#                            {'X': 0.35120266675949097, 'Y': 0.4263925850391388},
#                            {'X': 0.35120266675949097, 'Y': 0.4403003752231598},
#                            {'X': 0.15795785188674927,
#                             'Y': 0.4403003752231598}]},
#   'Id': '944d67b6-f967-4709-9695-df454560b420',
#   'Relationships': [{'Ids': ['bb52b79f-c7e7-4bb8-a2e4-4383150f77f9',
#                              '1be89592-2062-4a1b-b240-941ffcb53ad7',
#                              '49f2c167-1ee8-4e82-bf0c-0a9a4b088480'],
#                      'Type': 'CHILD'}],
#   'Text': 'Fund Transfer Complete'},
#  {'BlockType': 'LINE',
#   'Confidence': 99.8935317993164,
#   'Geometry': {'BoundingBox': {'Height': 0.013523665256798267,
#                                'Left': 0.4188205897808075,
#                                'Top': 0.42663347721099854,
#                                'Width': 0.08859296143054962},
#                'Polygon': [{'X': 0.4188205897808075, 'Y': 0.42663347721099854},
#                            {'X': 0.5074135661125183, 'Y': 0.42663347721099854},
#                            {'X': 0.5074135661125183, 'Y': 0.4401571452617645},
#                            {'X': 0.4188205897808075, 'Y': 0.4401571452617645}]},
#   'Id': 'dff3583f-2e02-4ff5-8c40-b532ed69d26c',
#   'Relationships': [{'Ids': ['54f3e878-62c2-4345-8a5a-2f65122353cb',
#                              '1b6db0ed-c025-4829-8053-e94ff2cf24ea'],
#                      'Type': 'CHILD'}],
#   'Text': 'In progress'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.86685180664062,
#   'Geometry': {'BoundingBox': {'Height': 0.0159549992531538,
#                                'Left': 0.32446542382240295,
#                                'Top': 0.0700971707701683,
#                                'Width': 0.0667736828327179},
#                'Polygon': [{'X': 0.32446542382240295, 'Y': 0.0700971707701683},
#                            {'X': 0.39123910665512085, 'Y': 0.0700971707701683},
#                            {'X': 0.39123910665512085, 'Y': 0.08605217188596725},
#                            {'X': 0.32446542382240295,
#                             'Y': 0.08605217188596725}]},
#   'Id': '42c0f75c-9f89-4e8b-9101-91eb61e800e5',
#   'Text': 'Land'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.81405639648438,
#   'Geometry': {'BoundingBox': {'Height': 0.016025349497795105,
#                                'Left': 0.39932993054389954,
#                                'Top': 0.07008354365825653,
#                                'Width': 0.08684363961219788},
#                'Polygon': [{'X': 0.39932993054389954, 'Y': 0.07008354365825653},
#                            {'X': 0.4861735701560974, 'Y': 0.07008354365825653},
#                            {'X': 0.4861735701560974, 'Y': 0.08610889315605164},
#                            {'X': 0.39932993054389954,
#                             'Y': 0.08610889315605164}]},
#   'Id': '8efc8e0c-9d9f-46a0-bb8e-067331bd9017',
#   'Text': 'Owner'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.92603302001953,
#   'Geometry': {'BoundingBox': {'Height': 0.015904439613223076,
#                                'Left': 0.4938323199748993,
#                                'Top': 0.06981603801250458,
#                                'Width': 0.10275092720985413},
#                'Polygon': [{'X': 0.4938323199748993, 'Y': 0.06981603801250458},
#                            {'X': 0.5965832471847534, 'Y': 0.06981603801250458},
#                            {'X': 0.5965832471847534, 'Y': 0.0857204794883728},
#                            {'X': 0.4938323199748993, 'Y': 0.0857204794883728}]},
#   'Id': '5474ab59-6ae9-4489-a6a3-c1bc16e83192',
#   'Text': 'Consent'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.89046478271484,
#   'Geometry': {'BoundingBox': {'Height': 0.015945205464959145,
#                                'Left': 0.6037513017654419,
#                                'Top': 0.07034729421138763,
#                                'Width': 0.07023990154266357},
#                'Polygon': [{'X': 0.6037513017654419, 'Y': 0.07034729421138763},
#                            {'X': 0.6739912033081055, 'Y': 0.07034729421138763},
#                            {'X': 0.6739912033081055, 'Y': 0.08629249781370163},
#                            {'X': 0.6037513017654419,
#                             'Y': 0.08629249781370163}]},
#   'Id': '24ac5cf5-da35-4222-a649-c8406974fd94',
#   'Text': 'Form'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.90869903564453,
#   'Geometry': {'BoundingBox': {'Height': 0.010880745947360992,
#                                'Left': 0.1578006148338318,
#                                'Top': 0.10606466978788376,
#                                'Width': 0.047634221613407135},
#                'Polygon': [{'X': 0.1578006148338318, 'Y': 0.10606466978788376},
#                            {'X': 0.20543482899665833, 'Y': 0.10606466978788376},
#                            {'X': 0.20543482899665833, 'Y': 0.11694541573524475},
#                            {'X': 0.1578006148338318,
#                             'Y': 0.11694541573524475}]},
#   'Id': '78be2dcb-e5db-4f2a-83ba-aea0856353e7',
#   'Text': 'Name'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.41557312011719,
#   'Geometry': {'BoundingBox': {'Height': 0.011279149912297726,
#                                'Left': 0.20987701416015625,
#                                'Top': 0.10546708852052689,
#                                'Width': 0.018870759755373},
#                'Polygon': [{'X': 0.20987701416015625, 'Y': 0.10546708852052689},
#                            {'X': 0.22874777019023895, 'Y': 0.10546708852052689},
#                            {'X': 0.22874777019023895, 'Y': 0.11674623936414719},
#                            {'X': 0.20987701416015625,
#                             'Y': 0.11674623936414719}]},
#   'Id': '7d45554e-efb9-49b4-a6db-835dbeefe718',
#   'Text': 'of'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.80995178222656,
#   'Geometry': {'BoundingBox': {'Height': 0.010929395444691181,
#                                'Left': 0.23064056038856506,
#                                'Top': 0.10592931509017944,
#                                'Width': 0.05499054118990898},
#                'Polygon': [{'X': 0.23064056038856506, 'Y': 0.10592931509017944},
#                            {'X': 0.28563109040260315, 'Y': 0.10592931509017944},
#                            {'X': 0.28563109040260315, 'Y': 0.11685871332883835},
#                            {'X': 0.23064056038856506,
#                             'Y': 0.11685871332883835}]},
#   'Id': '935538a0-b7f3-402e-86bd-0e93a7f3b2c3',
#   'Text': 'Owner'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.71688842773438,
#   'Geometry': {'BoundingBox': {'Height': 0.011225639842450619,
#                                'Left': 0.4188355803489685,
#                                'Top': 0.1057262122631073,
#                                'Width': 0.06548842042684555},
#                'Polygon': [{'X': 0.4188355803489685, 'Y': 0.1057262122631073},
#                            {'X': 0.48432400822639465, 'Y': 0.1057262122631073},
#                            {'X': 0.48432400822639465, 'Y': 0.1169518530368805},
#                            {'X': 0.4188355803489685, 'Y': 0.1169518530368805}]},
#   'Id': '7866ec06-8fdc-4c41-ab82-57c17b8b7d5b',
#   'Text': 'Shambu'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.8154296875,
#   'Geometry': {'BoundingBox': {'Height': 0.011632045730948448,
#                                'Left': 0.4885634183883667,
#                                'Top': 0.10553266853094101,
#                                'Width': 0.060089681297540665},
#                'Polygon': [{'X': 0.4885634183883667, 'Y': 0.10553266853094101},
#                            {'X': 0.5486531257629395, 'Y': 0.10553266853094101},
#                            {'X': 0.5486531257629395, 'Y': 0.1171647161245346},
#                            {'X': 0.4885634183883667, 'Y': 0.1171647161245346}]},
#   'Id': 'e6dd92e0-70a7-4e3d-be1e-c4e4dd7fb53e',
#   'Text': 'Sharma'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.89271545410156,
#   'Geometry': {'BoundingBox': {'Height': 0.011183849535882473,
#                                'Left': 0.15774068236351013,
#                                'Top': 0.1271410435438156,
#                                'Width': 0.04973850026726723},
#                'Polygon': [{'X': 0.15774068236351013, 'Y': 0.1271410435438156},
#                            {'X': 0.20747917890548706, 'Y': 0.1271410435438156},
#                            {'X': 0.20747917890548706, 'Y': 0.13832488656044006},
#                            {'X': 0.15774068236351013,
#                             'Y': 0.13832488656044006}]},
#   'Id': 'fa1f06c5-27ac-48b0-8745-0daeb37c1a72',
#   'Text': 'Phone'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.89010620117188,
#   'Geometry': {'BoundingBox': {'Height': 0.011144950054585934,
#                                'Left': 0.21188242733478546,
#                                'Top': 0.12712253630161285,
#                                'Width': 0.06551896780729294},
#                'Polygon': [{'X': 0.21188242733478546, 'Y': 0.12712253630161285},
#                            {'X': 0.2774013876914978, 'Y': 0.12712253630161285},
#                            {'X': 0.2774013876914978, 'Y': 0.13826748728752136},
#                            {'X': 0.21188242733478546,
#                             'Y': 0.13826748728752136}]},
#   'Id': '8215e14e-8ef0-4b2f-b944-5bc95430eddd',
#   'Text': 'Number'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.36761474609375,
#   'Geometry': {'BoundingBox': {'Height': 0.011496500112116337,
#                                'Left': 0.281453937292099,
#                                'Top': 0.12669622898101807,
#                                'Width': 0.02349942922592163},
#                'Polygon': [{'X': 0.281453937292099, 'Y': 0.12669622898101807},
#                            {'X': 0.30495336651802063, 'Y': 0.12669622898101807},
#                            {'X': 0.30495336651802063, 'Y': 0.13819272816181183},
#                            {'X': 0.281453937292099, 'Y': 0.13819272816181183}]},
#   'Id': '8037941b-60df-4139-b4f1-12f14d23fce8',
#   'Text': 'Of'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.63196563720703,
#   'Geometry': {'BoundingBox': {'Height': 0.011580999940633774,
#                                'Left': 0.4196041524410248,
#                                'Top': 0.1268470287322998,
#                                'Width': 0.11471471190452576},
#                'Polygon': [{'X': 0.4196041524410248, 'Y': 0.1268470287322998},
#                            {'X': 0.5343188643455505, 'Y': 0.1268470287322998},
#                            {'X': 0.5343188643455505, 'Y': 0.13842803239822388},
#                            {'X': 0.4196041524410248,
#                             'Y': 0.13842803239822388}]},
#   'Id': 'c1121f96-ecfd-46c1-a23d-48f94d56e85a',
#   'Text': '0120-1234569'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.85066986083984,
#   'Geometry': {'BoundingBox': {'Height': 0.011032859794795513,
#                                'Left': 0.1580643206834793,
#                                'Top': 0.14320598542690277,
#                                'Width': 0.04090448096394539},
#                'Polygon': [{'X': 0.1580643206834793, 'Y': 0.14320598542690277},
#                            {'X': 0.1989687979221344, 'Y': 0.14320598542690277},
#                            {'X': 0.1989687979221344, 'Y': 0.15423884987831116},
#                            {'X': 0.1580643206834793,
#                             'Y': 0.15423884987831116}]},
#   'Id': 'ee862bca-4f80-4835-8e03-ae3157240cbf',
#   'Text': 'Land'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.73748779296875,
#   'Geometry': {'BoundingBox': {'Height': 0.010848980396986008,
#                                'Left': 0.20318883657455444,
#                                'Top': 0.14344412088394165,
#                                'Width': 0.0542750284075737},
#                'Polygon': [{'X': 0.20318883657455444, 'Y': 0.14344412088394165},
#                            {'X': 0.25746387243270874, 'Y': 0.14344412088394165},
#                            {'X': 0.25746387243270874, 'Y': 0.15429310500621796},
#                            {'X': 0.20318883657455444,
#                             'Y': 0.15429310500621796}]},
#   'Id': '6d1b4a04-9f80-42d1-9753-2beef95bba10',
#   'Text': 'Owner'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.93701934814453,
#   'Geometry': {'BoundingBox': {'Height': 0.011053450405597687,
#                                'Left': 0.15814664959907532,
#                                'Top': 0.16475625336170197,
#                                'Width': 0.08461739122867584},
#                'Polygon': [{'X': 0.15814664959907532, 'Y': 0.16475625336170197},
#                            {'X': 0.24276404082775116, 'Y': 0.16475625336170197},
#                            {'X': 0.24276404082775116, 'Y': 0.17580969631671906},
#                            {'X': 0.15814664959907532,
#                             'Y': 0.17580969631671906}]},
#   'Id': '94a33dd8-c2f1-49f9-b99a-5395f17417c2',
#   'Text': 'Permanent'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.91378021240234,
#   'Geometry': {'BoundingBox': {'Height': 0.01121996995061636,
#                                'Left': 0.24668622016906738,
#                                'Top': 0.16449524462223053,
#                                'Width': 0.06491845846176147},
#                'Polygon': [{'X': 0.24668622016906738, 'Y': 0.16449524462223053},
#                            {'X': 0.31160467863082886, 'Y': 0.16449524462223053},
#                            {'X': 0.31160467863082886, 'Y': 0.17571520805358887},
#                            {'X': 0.24668622016906738,
#                             'Y': 0.17571520805358887}]},
#   'Id': '9c7826ce-6e6c-42f7-ada1-0e46476e91ec',
#   'Text': 'Address'},
#  {'BlockType': 'WORD',
#   'Confidence': 99.95372772216797,
#   'Geometry': {'BoundingBox': {'Height': 0.013653839938342571,
#                                'Left': 0.41905486583709717,
#                                'Top': 0.1646329164505005,
#                                'Width': 0.08206573128700256},
#                'Polygon': [{'X': 0.41905486583709717, 'Y': 0.1646329164505005},
#                            {'X': 0.5011206269264221, 'Y': 0.1646329164505005},
#                            {'X': 0.5011206269264221, 'Y': 0.17828676104545593},
# ...
#   'RowIndex': 9,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 3,
#   'ColumnSpan': 1,
#   'Confidence': 99.98334503173828,
#   'Geometry': {'BoundingBox': {'Height': 0.021754659712314606,
#                                'Left': 0.6436108350753784,
#                                'Top': 0.3141297698020935,
#                                'Width': 0.21285513043403625},
#                'Polygon': [{'X': 0.6436108350753784, 'Y': 0.3141297698020935},
#                            {'X': 0.8564659357070923, 'Y': 0.3141297698020935},
#                            {'X': 0.8564659357070923, 'Y': 0.3358844220638275},
#                            {'X': 0.6436108350753784, 'Y': 0.3358844220638275}]},
#   'Id': '0a9e773c-1c74-496a-a43a-617f2d0d75a0',
#   'RowIndex': 9,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 1,
#   'ColumnSpan': 1,
#   'Confidence': 99.98334503173828,
#   'Geometry': {'BoundingBox': {'Height': 0.020917942747473717,
#                                'Left': 0.15010227262973785,
#                                'Top': 0.3358844220638275,
#                                'Width': 0.26646310091018677},
#                'Polygon': [{'X': 0.15010227262973785, 'Y': 0.3358844220638275},
#                            {'X': 0.4165653586387634, 'Y': 0.3358844220638275},
#                            {'X': 0.4165653586387634, 'Y': 0.356802374124527},
#                            {'X': 0.15010227262973785, 'Y': 0.356802374124527}]},
#   'Id': '369da026-f12b-4c48-b71f-1cf622128fb3',
#   'Relationships': [{'Ids': ['fc37f83e-43fa-4143-b234-3eaf29ae501b',
#                              'ef02a71f-131c-42f0-b33b-1a7b574ac695',
#                              'b49ea5b4-c36d-410d-8995-e820196502b4'],
#                      'Type': 'CHILD'}],
#   'RowIndex': 10,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 2,
#   'ColumnSpan': 1,
#   'Confidence': 99.98334503173828,
#   'Geometry': {'BoundingBox': {'Height': 0.020917942747473717,
#                                'Left': 0.4165653586387634,
#                                'Top': 0.3358844220638275,
#                                'Width': 0.227045476436615},
#                'Polygon': [{'X': 0.4165653586387634, 'Y': 0.3358844220638275},
#                            {'X': 0.6436108350753784, 'Y': 0.3358844220638275},
#                            {'X': 0.6436108350753784, 'Y': 0.356802374124527},
#                            {'X': 0.4165653586387634, 'Y': 0.356802374124527}]},
#   'Id': 'f4d1acd8-52fa-470f-b952-aacc3a0f77b8',
#   'Relationships': [{'Ids': ['47564a43-38ce-454e-9da5-3c7bf1bd87ed',
#                              'c23b374e-5423-4bf6-84b7-ecdf9bc28fef'],
#                      'Type': 'CHILD'}],
#   'RowIndex': 10,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 3,
#   'ColumnSpan': 1,
#   'Confidence': 99.98334503173828,
#   'Geometry': {'BoundingBox': {'Height': 0.020917942747473717,
#                                'Left': 0.6436108350753784,
#                                'Top': 0.3358844220638275,
#                                'Width': 0.21285513043403625},
#                'Polygon': [{'X': 0.6436108350753784, 'Y': 0.3358844220638275},
#                            {'X': 0.8564659357070923, 'Y': 0.3358844220638275},
#                            {'X': 0.8564659357070923, 'Y': 0.356802374124527},
#                            {'X': 0.6436108350753784, 'Y': 0.356802374124527}]},
#   'Id': '00e88354-2a2f-4dc3-a592-d0ccce8e0436',
#   'Relationships': [{'Ids': ['b9f5735e-b6ba-4607-b250-5b3f892dfbf7',
#                              '78f3af00-e4c1-44fe-8ad2-44d3a8ba0268',
#                              '40bb6bdc-79b8-4a53-b889-69a429f656e7'],
#                      'Type': 'CHILD'}],
#   'RowIndex': 10,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 1,
#   'ColumnSpan': 1,
#   'Confidence': 99.98334503173828,
#   'Geometry': {'BoundingBox': {'Height': 0.021754659712314606,
#                                'Left': 0.15010227262973785,
#                                'Top': 0.356802374124527,
#                                'Width': 0.26646310091018677},
#                'Polygon': [{'X': 0.15010227262973785, 'Y': 0.356802374124527},
#                            {'X': 0.4165653586387634, 'Y': 0.356802374124527},
#                            {'X': 0.4165653586387634, 'Y': 0.378557026386261},
#                            {'X': 0.15010227262973785, 'Y': 0.378557026386261}]},
#   'Id': '4c1760ab-c493-4b25-8b45-053b3e8feba3',
#   'Relationships': [{'Ids': ['b9c746d5-9504-46a1-983f-667a98c0d75b',
#                              '5cdd0886-d45d-4396-8623-ac3e31511437',
#                              '3c26d046-8a3d-49e6-a687-d34e989e0ba6',
#                              '5d72601b-eff1-4fe8-a781-7a64c104167c'],
#                      'Type': 'CHILD'}],
#   'RowIndex': 11,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 2,
#   'ColumnSpan': 1,
#   'Confidence': 99.98334503173828,
#   'Geometry': {'BoundingBox': {'Height': 0.021754659712314606,
#                                'Left': 0.4165653586387634,
#                                'Top': 0.356802374124527,
#                                'Width': 0.227045476436615},
#                'Polygon': [{'X': 0.4165653586387634, 'Y': 0.356802374124527},
#                            {'X': 0.6436108350753784, 'Y': 0.356802374124527},
#                            {'X': 0.6436108350753784, 'Y': 0.378557026386261},
#                            {'X': 0.4165653586387634, 'Y': 0.378557026386261}]},
#   'Id': 'b5530294-1357-42bc-80b6-c01655bac89b',
#   'Relationships': [{'Ids': ['1bc566c9-ce7e-46aa-bf9a-7b4e9f29afcb'],
#                      'Type': 'CHILD'}],
#   'RowIndex': 11,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 3,
#   'ColumnSpan': 1,
#   'Confidence': 99.98334503173828,
#   'Geometry': {'BoundingBox': {'Height': 0.021754659712314606,
#                                'Left': 0.6436108350753784,
#                                'Top': 0.356802374124527,
#                                'Width': 0.21285513043403625},
#                'Polygon': [{'X': 0.6436108350753784, 'Y': 0.356802374124527},
#                            {'X': 0.8564659357070923, 'Y': 0.356802374124527},
#                            {'X': 0.8564659357070923, 'Y': 0.378557026386261},
#                            {'X': 0.6436108350753784, 'Y': 0.378557026386261}]},
#   'Id': '93da3dbb-823e-4608-9435-45482d43cd6e',
#   'Relationships': [{'Ids': ['907b36ef-ee37-430b-87d1-87014a106e3d',
#                              '84b14437-26ea-4272-96bc-e1fe7c06c12d',
#                              '66301fba-0e19-47ff-be02-7cc9adffc86f',
#                              'b578f9bc-7a5e-4984-ad3c-65a5e0818389'],
#                      'Type': 'CHILD'}],
#   'RowIndex': 11,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 1,
#   'ColumnSpan': 1,
#   'Confidence': 99.98334503173828,
#   'Geometry': {'BoundingBox': {'Height': 0.020917942747473717,
#                                'Left': 0.15010227262973785,
#                                'Top': 0.378557026386261,
#                                'Width': 0.26646310091018677},
#                'Polygon': [{'X': 0.15010227262973785, 'Y': 0.378557026386261},
#                            {'X': 0.4165653586387634, 'Y': 0.378557026386261},
#                            {'X': 0.4165653586387634, 'Y': 0.39947494864463806},
#                            {'X': 0.15010227262973785,
#                             'Y': 0.39947494864463806}]},
#   'Id': '04424ba8-8c3e-44a3-b66d-3e49adb21222',
#   'Relationships': [{'Ids': ['3953883c-6da8-4301-be19-8fa4327b3ca2',
#                              'a5ff092f-901a-443b-9dd6-55a5eaf09999',
#                              '435f2683-b4cb-4505-9eb5-fc44cc7870fb',
#                              '1f13b512-bc00-4425-acc2-de8b0b79cf5c'],
#                      'Type': 'CHILD'}],
#   'RowIndex': 12,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 2,
#   'ColumnSpan': 1,
#   'Confidence': 99.98334503173828,
#   'Geometry': {'BoundingBox': {'Height': 0.020917942747473717,
#                                'Left': 0.4165653586387634,
#                                'Top': 0.378557026386261,
#                                'Width': 0.227045476436615},
#                'Polygon': [{'X': 0.4165653586387634, 'Y': 0.378557026386261},
#                            {'X': 0.6436108350753784, 'Y': 0.378557026386261},
#                            {'X': 0.6436108350753784, 'Y': 0.39947494864463806},
#                            {'X': 0.4165653586387634,
#                             'Y': 0.39947494864463806}]},
#   'Id': 'ab2a8c9a-b8c7-4979-b232-2eb5346cfdca',
#   'Relationships': [{'Ids': ['27e58a3e-73b3-4da6-9f23-4c85e2e94e5f'],
#                      'Type': 'CHILD'}],
#   'RowIndex': 12,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 3,
#   'ColumnSpan': 1,
#   'Confidence': 99.98334503173828,
#   'Geometry': {'BoundingBox': {'Height': 0.020917942747473717,
#                                'Left': 0.6436108350753784,
#                                'Top': 0.378557026386261,
#                                'Width': 0.21285513043403625},
#                'Polygon': [{'X': 0.6436108350753784, 'Y': 0.378557026386261},
#                            {'X': 0.8564659357070923, 'Y': 0.378557026386261},
#                            {'X': 0.8564659357070923, 'Y': 0.39947494864463806},
#                            {'X': 0.6436108350753784,
#                             'Y': 0.39947494864463806}]},
#   'Id': 'faa67e54-a044-4635-85b1-ce8a34b23608',
#   'RowIndex': 12,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 1,
#   'ColumnSpan': 1,
#   'Confidence': 99.98334503173828,
#   'Geometry': {'BoundingBox': {'Height': 0.020917942747473717,
#                                'Left': 0.15010227262973785,
#                                'Top': 0.39947494864463806,
#                                'Width': 0.26646310091018677},
#                'Polygon': [{'X': 0.15010227262973785, 'Y': 0.39947494864463806},
#                            {'X': 0.4165653586387634, 'Y': 0.39947494864463806},
#                            {'X': 0.4165653586387634, 'Y': 0.4203929007053375},
#                            {'X': 0.15010227262973785,
#                             'Y': 0.4203929007053375}]},
#   'Id': '4b31eea9-cf4e-41e6-be01-192a9d546d34',
#   'Relationships': [{'Ids': ['779c6801-5592-469c-902b-8795601aac31',
#                              '5cec1b83-e129-4783-aa4d-bd3949eed78c',
#                              '6a43499f-35e2-4e15-95e1-90567d2f5b02'],
#                      'Type': 'CHILD'}],
#   'RowIndex': 13,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 2,
#   'ColumnSpan': 1,
#   'Confidence': 99.98334503173828,
#   'Geometry': {'BoundingBox': {'Height': 0.020917942747473717,
#                                'Left': 0.4165653586387634,
#                                'Top': 0.39947494864463806,
#                                'Width': 0.227045476436615},
#                'Polygon': [{'X': 0.4165653586387634, 'Y': 0.39947494864463806},
#                            {'X': 0.6436108350753784, 'Y': 0.39947494864463806},
#                            {'X': 0.6436108350753784, 'Y': 0.4203929007053375},
#                            {'X': 0.4165653586387634, 'Y': 0.4203929007053375}]},
#   'Id': '0e211e46-85e6-4326-ab88-89c47916df5b',
#   'Relationships': [{'Ids': ['03ed1671-b141-4ac9-a336-292b32257d92'],
#                      'Type': 'CHILD'}],
#   'RowIndex': 13,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 3,
#   'ColumnSpan': 1,
#   'Confidence': 99.98334503173828,
#   'Geometry': {'BoundingBox': {'Height': 0.020917942747473717,
#                                'Left': 0.6436108350753784,
#                                'Top': 0.39947494864463806,
#                                'Width': 0.21285513043403625},
#                'Polygon': [{'X': 0.6436108350753784, 'Y': 0.39947494864463806},
#                            {'X': 0.8564659357070923, 'Y': 0.39947494864463806},
#                            {'X': 0.8564659357070923, 'Y': 0.4203929007053375},
#                            {'X': 0.6436108350753784, 'Y': 0.4203929007053375}]},
#   'Id': 'b84de749-577c-42b5-8c3f-dc3907b6bde8',
#   'RowIndex': 13,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 1,
#   'ColumnSpan': 1,
#   'Confidence': 99.98334503173828,
#   'Geometry': {'BoundingBox': {'Height': 0.02510152943432331,
#                                'Left': 0.15010227262973785,
#                                'Top': 0.4203929007053375,
#                                'Width': 0.26646310091018677},
#                'Polygon': [{'X': 0.15010227262973785, 'Y': 0.4203929007053375},
#                            {'X': 0.4165653586387634, 'Y': 0.4203929007053375},
#                            {'X': 0.4165653586387634, 'Y': 0.4454944431781769},
#                            {'X': 0.15010227262973785,
#                             'Y': 0.4454944431781769}]},
#   'Id': '82c404b1-ce91-4d81-9886-9ff4ddea2123',
#   'Relationships': [{'Ids': ['bb52b79f-c7e7-4bb8-a2e4-4383150f77f9',
#                              '1be89592-2062-4a1b-b240-941ffcb53ad7',
#                              '49f2c167-1ee8-4e82-bf0c-0a9a4b088480'],
#                      'Type': 'CHILD'}],
#   'RowIndex': 14,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 2,
#   'ColumnSpan': 1,
#   'Confidence': 99.98334503173828,
#   'Geometry': {'BoundingBox': {'Height': 0.02510152943432331,
#                                'Left': 0.4165653586387634,
#                                'Top': 0.4203929007053375,
#                                'Width': 0.227045476436615},
#                'Polygon': [{'X': 0.4165653586387634, 'Y': 0.4203929007053375},
#                            {'X': 0.6436108350753784, 'Y': 0.4203929007053375},
#                            {'X': 0.6436108350753784, 'Y': 0.4454944431781769},
#                            {'X': 0.4165653586387634, 'Y': 0.4454944431781769}]},
#   'Id': '65993852-ce95-4938-924e-c1c8b1b31de5',
#   'Relationships': [{'Ids': ['54f3e878-62c2-4345-8a5a-2f65122353cb',
#                              '1b6db0ed-c025-4829-8053-e94ff2cf24ea'],
#                      'Type': 'CHILD'}],
#   'RowIndex': 14,
#   'RowSpan': 1},
#  {'BlockType': 'CELL',
#   'ColumnIndex': 3,
#   'ColumnSpan': 1,
#   'Confidence': 99.98334503173828,
#   'Geometry': {'BoundingBox': {'Height': 0.02510152943432331,
#                                'Left': 0.6436108350753784,
#                                'Top': 0.4203929007053375,
#                                'Width': 0.21285513043403625},
#                'Polygon': [{'X': 0.6436108350753784, 'Y': 0.4203929007053375},
#                            {'X': 0.8564659357070923, 'Y': 0.4203929007053375},
#                            {'X': 0.8564659357070923, 'Y': 0.4454944431781769},
#                            {'X': 0.6436108350753784, 'Y': 0.4454944431781769}]},
#   'Id': '32ab861f-e9f4-420b-80cf-03767dea264f',
#   'RowIndex': 14,
#   'RowSpan': 1}]
# CSV OUTPUT FILE:  Land Owner Consent Form.csv
# {
#     "Land ": [
#         "Owner Consent Form ",
#         "",
#         ""
#     ],
#     "Name of Owner ": [
#         "Shambu Sharma ",
#         "",
#         ""
#     ],
#     "Phone Number Of Land Owner ": [
#         "0120-1234569 ",
#         "",
#         ""
#     ],
#     "Permanent Address of Land Owner ": [
#         "Balampur",
#         " Uttar Pradesh ",
#         "",
#         ""
#     ],
#     "Name of buyer organization/ Individual ": [
#         "AAI ",
#         "",
#         ""
#     ],
#     "Phone Number Of Owner ": [
#         "011-5669742 ",
#         "",
#         ""
#     ],
#     "Permanent Address organization Individual ": [
#         "New Delhi ",
#         "A-123",
#         " Safdarjung Enclave ",
#         ""
#     ],
#     "Total Area of Land ": [
#         "20acres ",
#         "",
#         ""
#     ],
#     "Total Cost of Land ": [
#         "2cr ",
#         "",
#         ""
#     ],
#     "Address of Plot ": [
#         "Jewar Village ",
#         "X-987 opposite Mandir ",
#         ""
#     ],
#     "Approval from Local Authority ": [
#         "Done ",
#         "On 7-5-19 at 14:00 ",
#         ""
#     ],
#     "Loan taken by buyer ": [
#         "None ",
#         "",
#         ""
#     ],
#     "Total Capital inversted ": [
#         "2cr ",
#         "",
#         ""
#     ],
#     "Fund Transfer Complete ": [
#         "In progress ",
#         "",
#         ""
#     ]
# }

# %%
# Moving generated file to specific folder of that name
os.mkdir(output_file_name)
shutil.move(csv_output_file,output_file_name+'/'+csv_output_file)
shutil.move(json_output_file,output_file_name+'/'+json_output_file)
# Out:
# 'Land Owner Consent Form/Land Owner Consent Form.json'
